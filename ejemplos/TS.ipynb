# %% [markdown]
# # Series de Tiempo

# %%
import pandas as pd
from numpy import mean
from numpy import median
from numpy import array
import matplotlib.pyplot as plt
from matplotlib import pyplot
import random
from math import sqrt
from sklearn.metrics import mean_squared_error

#
from warnings import catch_warnings
from warnings import filterwarnings

# La librería statsmodel tiene implementaciones de SARIMA y de Holt-Winters
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# Si el computador tiene procesadores múltiples, se aprovecharán
#from multiprocessing import cpu_count

from multiprocess import cpu_count
from joblib import Parallel

from joblib import delayed

# %% [markdown]
# # Métodos (funciones vistas en clase)

# %%
def division_entreno_prueba(datos, n_prueba):
    return datos[:-n_prueba], datos[-n_prueba:]

# %%
def medir_rmse(actual, predicho):
    return sqrt(mean_squared_error(actual, predicho))

# %%
# validación "walk-forward" para datos univariados
def validacion_al_frente(datos, n_prueba, metodo, cfg):
    predicciones = []
    # dividir el conjunto de datos
    entreno, prueba = division_entreno_prueba(datos, n_prueba)
    # grabar la historia con el conjunto de datos de entrenamiento
    historia = [x for x in entreno]
    # pasar por cada incremento de tiempo en el conjunto de prueba
    for i in range(len(prueba)):
        # ajustar el modelo a los datos y predecir los datos históricos
        if metodo == "promedio":
            yhat = prediccion_promedio(historia, cfg)
        elif metodo == "sarima":
            yhat = prediccion_sarima(historia, cfg)
        elif metodo == "exp":
            yhat = prediccion_alisamiento_exp(historia, cfg)
        # agregar el dato predicho en la lista de preducciones
        predicciones.append(yhat)
        # agregar la observación a la historia para la siguiente iteración
        historia.append(prueba[i])
    # estimar el error de las predicciones
    error = medir_rmse(prueba, predicciones)
    return [error, predicciones]

# %%
def busqueda_malla(datos, lista_cfg, n_prueba, metodo = "sarima", paralelo = True):
    resultados = None
    if paralelo:
        # ejecutar las configuraciones en paralelo
        executor = Parallel(n_jobs = cpu_count(), backend = 'multiprocessing') 
        tareas = (delayed(calificar_modelo)(datos, n_prueba, metodo, cfg) for cfg in lista_cfg) 
        resultados = executor(tareas)
    else:
        resultados = [calificar_modelo(datos, n_prueba, metodo, cfg) for cfg in lista_cfg]
    # eliminar resultados vacíos
    resultados = [r for r in resultados if r[1] != None]
    return resultados

# %%
def calificar_modelo(datos, n_prueba, metodo, cfg, debug = False):
    resultado = None
    predicciones = None
    # convertir la confiuración a una llave
    llave = str(cfg)
    if debug:
        resultado, predicciones = validacion_al_frente(datos, n_prueba, metodo, cfg)
    else:
        # una falla durante la validación del modelo sugiere una configuración inestable
        try:
        # nunca mostrar advertencias cuando se busca en malla...demasiado "ruido"
            with catch_warnings():
                filterwarnings("ignore")
                resultado, predicciones = validacion_al_frente(datos, n_prueba, metodo, cfg)
        except:
            error = None
    if resultado is not None:
        print(f' > Modelo{llave} {resultado:.3f}')
    return (llave, resultado, predicciones)

# %%
def encontrar_mejor_solucion(series, nombre, metodo = "sarima", muestra = False):
    datos = series.values
    resultados = []
    # dividir los datos
    n_prueba = int(len(datos) * 0.2) # porcenta usado para prueba
    long_max = len(datos) - n_prueba
    print(f"Tamaño Entrenamiento {long_max}")
    print(f"Tamaño Prueba {n_prueba}")

    # configuraciones de los modelos
    if metodo == "sarima":
        print(f"Encontrando la mejor solución para {metodo}")
        lista_cfg = config_sarima()
    elif metodo == "promedio":
        print(f"Encontrando la mejor solución para {metodo}")
        lista_cfg = config_simple(long_max)
    elif metodo == "exp":
        print(f"Encontrando la mejor solución para {metodo}")
        lista_cfg = config_alisamiento_exp()
        datos = datos[:,0]
    # muestrear algunos
    if muestra:
        lista_cfg_azar = random.sample(lista_cfg, k = 25)
        while len(resultados) < 5:
            lista_cfg_azar = random.sample(lista_cfg, k = 25)
            resultados += busqueda_malla(datos, lista_cfg_azar, n_prueba, metodo)
    else:
        # búsqueda en malla
        resultados = busqueda_malla(datos, lista_cfg, n_prueba, metodo, False)
        
    
    # ordenan las configuraciones por error, ascendente
    resultados.sort(key = lambda tup: tup[1])


    print('terminado')
    # listar las mejores 3 configuraciones
    for cfg, error, predicciones in resultados[:3]:
        print(cfg, error)

    # desplegar
    entreno, prueba = division_entreno_prueba(datos, n_prueba)
    prediccion = pd.DataFrame(list(entreno.flatten()) + resultados[0][2])
    ax = pd.DataFrame(datos).plot(label = "Original") # Datos originales
    prediccion.plot(ax = ax, alpha = .7, figsize = (14,7))
    # Esconder las líneas de malla de la gráfica
    # ax.grid(False)

    # Esconder las marcas en los ejes
    #ax.set_xticks([])
    #ax.set_yticks([])
    
    plt.savefig(f"{nombre}_{metodo}.png", transparent = True)
    plt.show()

# %% [markdown]
# # Predicción Promedio (Simple)

# %%
def config_simple(long_max, offsets = [1]):
    configs = []
    for i in range(1, long_max + 1):
        for t in ['mediana',"promedio"]:
            cfg = [i, t]
            configs.append(cfg)
    return configs

# prediccion de un paso por promedio
def prediccion_promedio(historia, config):
    n, tipo_promedio = config
    if tipo_promedio == 'promedio':
        return mean(historia[-n:])
    return median(historia[-n:])

# %% [markdown]
# # Ejemplo "simplón"

# %% [markdown]
# Mostrar al algoritmo siempre un conjunto más del conjunto prueba y dejar que prediga el siguiente, en forma iterativa.  Luego comparar la predicción entera al conjunto de prueba utilizando el error cuadrado medio.

# %%
series = pd.read_csv('daily-total-female-births.csv', header=0, index_col=0)
datos = series.values
n_prueba = 100
long_max = len(datos) - n_prueba
cfg = config_simple(long_max)[1]
entreno = datos[:-n_prueba]
prueba = datos[-n_prueba:]
historia = [x for x in entreno]    
predicciones = []
for i in range(len(prueba)):
    yhat = prediccion_promedio(historia, cfg)
    predicciones.append(yhat)
    historia.append(prueba[i])

error = sqrt(mean_squared_error(prueba, predicciones))
error
# Out:
# 7.892401408950257

# %% [markdown]
# # Predicción SARIMA

# %%
def prediccion_sarima(historia, config):
    orden, orden_estacional, tendencia = config
    # definir el modelo
    modelo = SARIMAX(historia, order = orden, seasonal_order = orden_estacional, trend = tendencia,
      enforce_stationarity = False, enforce_invertibility = False)
    # ajustar el model con los datos
    modelo_ajustado = modelo.fit(disp = False)
    # hacer la predicción de un paso
    yhat = modelo_ajustado.predict(len(historia), len(historia))
    return yhat[0]

def config_sarima(estacional = [0]):
    modelos = []
    # definir las listas de configuración
    p_params = [0, 1, 2]
    d_params = [0, 1]
    q_params = [0, 1, 2]
    t_params = ['n','c','t','ct'] 
    P_params = [0, 1, 2]
    D_params = [0, 1]
    Q_params = [0, 1, 2]
    m_params = estacional
    # crear instancias de configuración
    for p in p_params:
        for d in d_params:
            for q in q_params:
                for t in t_params:
                    for P in P_params:
                        for D in D_params:
                            for Q in Q_params:
                                for m in m_params:
                                    cfg = [(p,d,q), (P,D,Q,m), t]
                                    modelos.append(cfg)
    return modelos

# %% [markdown]
# # Alisamiento Exponencial - Holt Winters

# %%
def prediccion_alisamiento_exp(historia, config):
    t, d, s, p, b, r = config
    # definir el modelo
    historia = array(historia)
    modelo = ExponentialSmoothing(historia, trend = t, damped = d, seasonal = s, 
                                  seasonal_periods = p)
    # ajustar el modelo con los datos
    modelo_ajustado = modelo.fit(optimized = True, use_boxcox = b, remove_bias = r)
    # predecir un paso
    yhat = modelo_ajustado.predict(len(historia), len(historia))
    return yhat[0]

def config_alisamiento_exp(estacional = [None]): 
    modelos = []
    # definir las listas de config
    t_params = ['add', 'mul', None]
    d_params = [True, False] 
    s_params = ['add', 'mul', None]
    p_params = estacional
    b_params = [True, False]
    r_params = [True, False]
    # crear instancias de configuración
    for t in t_params:
        for d in d_params:
            for s in s_params:
                for p in p_params:
                    for b in b_params:
                        for r in r_params:
                            cfg = [t,d,s,p,b,r]
                            modelos.append(cfg)
    return modelos

# %% [markdown]
# # Caso: Ninguna tendencia - Nacimiento niñas

# %%
series = pd.read_csv('daily-total-female-births.csv', header=0, 
                     parse_dates = ["Date"], index_col = 0)
#import seaborn; seaborn.set()
series.plot(figsize=(16,10))
plt.savefig('nac_fem.png', transparent = True)

# %%
series = pd.read_csv('daily-total-female-births.csv', header = 0, index_col = 0)
nombre = "nacimiento-feminas"
encontrar_mejor_solucion(series, nombre, metodo = "promedio")
encontrar_mejor_solucion(series, nombre, metodo = "sarima")
encontrar_mejor_solucion(series, nombre, metodo = "exp")
# Out:
# Tamaño Entrenamiento 292
# Tamaño Prueba 73
# Encontrando la mejor solución para promedio

# %% [markdown]
# # Caso:  Con Tendencia - Ventas Shampoo

# %%
series = pd.read_csv('shampoo.csv', header=0)
series["Year"] = [1998] * 12 + [1999] * 12 + [2000] * 12
series["Month"] = list(range(1,13)) * 3
series["Date"] = series["Month"].apply(str) + "-" + series["Year"].apply(str)
series['date']  = pd.to_datetime(series["Date"])
series = series[["date","Sales"]]
series.set_index(['date'],inplace = True)

import seaborn; seaborn.set()
series.plot(figsize = (16,10))
plt.savefig('shampoo.png')

# %%
series = pd.read_csv('shampoo.csv', header = 0, index_col = 0)
nombre="shampoo"
encontrar_mejor_solucion(series, nombre, metodo = "promedio")
encontrar_mejor_solucion(series, nombre, metodo = "sarima")
encontrar_mejor_solucion(series, nombre, metodo = "exp")

# %% [markdown]
# # Caso:  Con Estacionalidad - Temperatura

# %%
series = pd.read_csv('monthly-mean-temp.csv', header = 0, parse_dates = ["Month"])
series.set_index(['Month'],inplace=True)
import seaborn; seaborn.set()
series.plot(figsize = (16,10))
plt.savefig('temp.png')

# %%
series = pd.read_csv('monthly-mean-temp.csv', header = 0, index_col = 0)
nombre = "temp"
encontrar_mejor_solucion(series, nombre, metodo = "promedio")
#encontrar_mejor_solucion(series, nombre, metodo = "sarima")
# Out:
# Tamaño Entrenamiento 192
# Tamaño Prueba 48
# Encontrando la mejor solución para promedio
#  > Modelo[1, 'mediana'] 5.144
#  > Modelo[1, 'promedio'] 5.144
#  > Modelo[2, 'mediana'] 6.595
#  > Modelo[2, 'promedio'] 6.595
#  > Modelo[3, 'mediana'] 8.336
#  > Modelo[3, 'promedio'] 8.144
#  > Modelo[4, 'mediana'] 9.714
#  > Modelo[4, 'promedio'] 9.405
#  > Modelo[5, 'mediana'] 11.176
#  > Modelo[5, 'promedio'] 10.343
#  > Modelo[6, 'mediana'] 11.964
#  > Modelo[6, 'promedio'] 10.946
#  > Modelo[7, 'mediana'] 12.716
#  > Modelo[7, 'promedio'] 11.168
#  > Modelo[8, 'mediana'] 12.263
#  > Modelo[8, 'promedio'] 11.018
#  > Modelo[9, 'mediana'] 11.490
#  > Modelo[9, 'promedio'] 10.560
#  > Modelo[10, 'mediana'] 10.721
#  > Modelo[10, 'promedio'] 9.887
#  > Modelo[11, 'mediana'] 9.883
#  > Modelo[11, 'promedio'] 9.113
#  > Modelo[12, 'mediana'] 8.412
#  > Modelo[12, 'promedio'] 8.384
#  > Modelo[13, 'mediana'] 7.341
#  > Modelo[13, 'promedio'] 7.861
#  > Modelo[14, 'mediana'] 7.133
#  > Modelo[14, 'promedio'] 7.655
#  > Modelo[15, 'mediana'] 7.581
#  > Modelo[15, 'promedio'] 7.770
#  > Modelo[16, 'mediana'] 8.363
#  > Modelo[16, 'promedio'] 8.130
#  > Modelo[17, 'mediana'] 9.046
#  > Modelo[17, 'promedio'] 8.566
#  > Modelo[18, 'mediana'] 9.522
#  > Modelo[18, 'promedio'] 8.977
#  > Modelo[19, 'mediana'] 9.881
#  > Modelo[19, 'promedio'] 9.272
#  > Modelo[20, 'mediana'] 10.038
#  > Modelo[20, 'promedio'] 9.388
#  > Modelo[21, 'mediana'] 10.058
#  > Modelo[21, 'promedio'] 9.321
#  > Modelo[22, 'mediana'] 9.687
#  > Modelo[22, 'promedio'] 9.074
#  > Modelo[23, 'mediana'] 9.226
#  > Modelo[23, 'promedio'] 8.726
#  > Modelo[24, 'mediana'] 8.380
#  > Modelo[24, 'promedio'] 8.354
#  > Modelo[25, 'mediana'] 7.720
#  > Modelo[25, 'promedio'] 8.062
#  > Modelo[26, 'mediana'] 7.633
#  > Modelo[26, 'promedio'] 7.923
#  > Modelo[27, 'mediana'] 7.827
#  > Modelo[27, 'promedio'] 7.970
#  > Modelo[28, 'mediana'] 8.187
#  > Modelo[28, 'promedio'] 8.168
#  > Modelo[29, 'mediana'] 8.670
#  > Modelo[29, 'promedio'] 8.445
#  > Modelo[30, 'mediana'] 9.060
#  > Modelo[30, 'promedio'] 8.723
#  > Modelo[31, 'mediana'] 9.306
#  > Modelo[31, 'promedio'] 8.928
#  > Modelo[32, 'mediana'] 9.439
#  > Modelo[32, 'promedio'] 9.025
#  > Modelo[33, 'mediana'] 9.466
#  > Modelo[33, 'promedio'] 8.996
#  > Modelo[34, 'mediana'] 9.273
#  > Modelo[34, 'promedio'] 8.853
#  > Modelo[35, 'mediana'] 9.035
#  > Modelo[35, 'promedio'] 8.625
#  > Modelo[36, 'mediana'] 8.475
#  > Modelo[36, 'promedio'] 8.370
#  > Modelo[37, 'mediana'] 8.031
#  > Modelo[37, 'promedio'] 8.160
#  > Modelo[38, 'mediana'] 7.885
#  > Modelo[38, 'promedio'] 8.057
#  > Modelo[39, 'mediana'] 7.921
#  > Modelo[39, 'promedio'] 8.072
#  > Modelo[40, 'mediana'] 8.198
#  > Modelo[40, 'promedio'] 8.200
#  > Modelo[41, 'mediana'] 8.531
#  > Modelo[41, 'promedio'] 8.395
#  > Modelo[42, 'mediana'] 8.833
#  > Modelo[42, 'promedio'] 8.599
#  > Modelo[43, 'mediana'] 9.057
#  > Modelo[43, 'promedio'] 8.761
#  > Modelo[44, 'mediana'] 9.164
#  > Modelo[44, 'promedio'] 8.839
#  > Modelo[45, 'mediana'] 9.196
#  > Modelo[45, 'promedio'] 8.822
#  > Modelo[46, 'mediana'] 9.077
#  > Modelo[46, 'promedio'] 8.711
#  > Modelo[47, 'mediana'] 8.920
#  > Modelo[47, 'promedio'] 8.540
#  > Modelo[48, 'mediana'] 8.499
#  > Modelo[48, 'promedio'] 8.352
#  > Modelo[49, 'mediana'] 8.143
#  > Modelo[49, 'promedio'] 8.200
#  > Modelo[50, 'mediana'] 8.019
#  > Modelo[50, 'promedio'] 8.123
#  > Modelo[51, 'mediana'] 8.047
#  > Modelo[51, 'promedio'] 8.142
#  > Modelo[52, 'mediana'] 8.234
#  > Modelo[52, 'promedio'] 8.236
#  > Modelo[53, 'mediana'] 8.486
#  > Modelo[53, 'promedio'] 8.375
#  > Modelo[54, 'mediana'] 8.729
#  > Modelo[54, 'promedio'] 8.522
#  > Modelo[55, 'mediana'] 8.943
#  > Modelo[55, 'promedio'] 8.638
#  > Modelo[56, 'mediana'] 9.035
#  > Modelo[56, 'promedio'] 8.700
#  > Modelo[57, 'mediana'] 9.071
#  > Modelo[57, 'promedio'] 8.691
#  > Modelo[58, 'mediana'] 8.974
#  > Modelo[58, 'promedio'] 8.614
#  > Modelo[59, 'mediana'] 8.845
#  > Modelo[59, 'promedio'] 8.484
#  > Modelo[60, 'mediana'] 8.531
#  > Modelo[60, 'promedio'] 8.340
#  > Modelo[61, 'mediana'] 8.249
#  > Modelo[61, 'promedio'] 8.214
#  > Modelo[62, 'mediana'] 8.091
#  > Modelo[62, 'promedio'] 8.148
#  > Modelo[63, 'mediana'] 8.102
#  > Modelo[63, 'promedio'] 8.157
#  > Modelo[64, 'mediana'] 8.268
#  > Modelo[64, 'promedio'] 8.232
#  > Modelo[65, 'mediana'] 8.482
#  > Modelo[65, 'promedio'] 8.352
#  > Modelo[66, 'mediana'] 8.708
#  > Modelo[66, 'promedio'] 8.477
#  > Modelo[67, 'mediana'] 8.905
#  > Modelo[67, 'promedio'] 8.577
#  > Modelo[68, 'mediana'] 8.971
#  > Modelo[68, 'promedio'] 8.631
#  > Modelo[69, 'mediana'] 8.993
#  > Modelo[69, 'promedio'] 8.625
#  > Modelo[70, 'mediana'] 8.898
#  > Modelo[70, 'promedio'] 8.562
#  > Modelo[71, 'mediana'] 8.745
#  > Modelo[71, 'promedio'] 8.456
#  > Modelo[72, 'mediana'] 8.540
#  > Modelo[72, 'promedio'] 8.336
#  > Modelo[73, 'mediana'] 8.355
#  > Modelo[73, 'promedio'] 8.239
#  > Modelo[74, 'mediana'] 8.190
#  > Modelo[74, 'promedio'] 8.185
#  > Modelo[75, 'mediana'] 8.181
#  > Modelo[75, 'promedio'] 8.193
#  > Modelo[76, 'mediana'] 8.315
#  > Modelo[76, 'promedio'] 8.255
#  > Modelo[77, 'mediana'] 8.502
#  > Modelo[77, 'promedio'] 8.352
#  > Modelo[78, 'mediana'] 8.694
#  > Modelo[78, 'promedio'] 8.454
#  > Modelo[79, 'mediana'] 8.845
#  > Modelo[79, 'promedio'] 8.537
#  > Modelo[80, 'mediana'] 8.918
#  > Modelo[80, 'promedio'] 8.578
#  > Modelo[81, 'mediana'] 8.952
#  > Modelo[81, 'promedio'] 8.570
#  > Modelo[82, 'mediana'] 8.843
#  > Modelo[82, 'promedio'] 8.514
#  > Modelo[83, 'mediana'] 8.691
#  > Modelo[83, 'promedio'] 8.423
#  > Modelo[84, 'mediana'] 8.551
#  > Modelo[84, 'promedio'] 8.321
#  > Modelo[85, 'mediana'] 8.435
#  > Modelo[85, 'promedio'] 8.237
#  > Modelo[86, 'mediana'] 8.267
#  > Modelo[86, 'promedio'] 8.195
#  > Modelo[87, 'mediana'] 8.250
#  > Modelo[87, 'promedio'] 8.205
#  > Modelo[88, 'mediana'] 8.390
#  > Modelo[88, 'promedio'] 8.262
#  > Modelo[89, 'mediana'] 8.562
#  > Modelo[89, 'promedio'] 8.346
#  > Modelo[90, 'mediana'] 8.717
#  > Modelo[90, 'promedio'] 8.438
#  > Modelo[91, 'mediana'] 8.839
#  > Modelo[91, 'promedio'] 8.510
#  > Modelo[92, 'mediana'] 8.921
#  > Modelo[92, 'promedio'] 8.546
#  > Modelo[93, 'mediana'] 8.987
#  > Modelo[93, 'promedio'] 8.538
#  > Modelo[94, 'mediana'] 8.828
#  > Modelo[94, 'promedio'] 8.490
#  > Modelo[95, 'mediana'] 8.605
#  > Modelo[95, 'promedio'] 8.414
#  > Modelo[96, 'mediana'] 8.552
#  > Modelo[96, 'promedio'] 8.328
#  > Modelo[97, 'mediana'] 8.506
#  > Modelo[97, 'promedio'] 8.254
#  > Modelo[98, 'mediana'] 8.307
#  > Modelo[98, 'promedio'] 8.213
#  > Modelo[99, 'mediana'] 8.285
#  > Modelo[99, 'promedio'] 8.219
#  > Modelo[100, 'mediana'] 8.421
#  > Modelo[100, 'promedio'] 8.266
#  > Modelo[101, 'mediana'] 8.572
#  > Modelo[101, 'promedio'] 8.341
#  > Modelo[102, 'mediana'] 8.724
#  > Modelo[102, 'promedio'] 8.422
#  > Modelo[103, 'mediana'] 8.859
#  > Modelo[103, 'promedio'] 8.488
#  > Modelo[104, 'mediana'] 8.916
#  > Modelo[104, 'promedio'] 8.522
#  > Modelo[105, 'mediana'] 8.951
#  > Modelo[105, 'promedio'] 8.517
#  > Modelo[106, 'mediana'] 8.795
#  > Modelo[106, 'promedio'] 8.474
#  > Modelo[107, 'mediana'] 8.577
#  > Modelo[107, 'promedio'] 8.405
#  > Modelo[108, 'mediana'] 8.541
#  > Modelo[108, 'promedio'] 8.329
#  > Modelo[109, 'mediana'] 8.510
#  > Modelo[109, 'promedio'] 8.267
#  > Modelo[110, 'mediana'] 8.318
#  > Modelo[110, 'promedio'] 8.233
#  > Modelo[111, 'mediana'] 8.287
#  > Modelo[111, 'promedio'] 8.236
#  > Modelo[112, 'mediana'] 8.416
#  > Modelo[112, 'promedio'] 8.276
#  > Modelo[113, 'mediana'] 8.563
#  > Modelo[113, 'promedio'] 8.339
#  > Modelo[114, 'mediana'] 8.695
#  > Modelo[114, 'promedio'] 8.410
#  > Modelo[115, 'mediana'] 8.808
#  > Modelo[115, 'promedio'] 8.469
#  > Modelo[116, 'mediana'] 8.857
#  > Modelo[116, 'promedio'] 8.502
#  > Modelo[117, 'mediana'] 8.888
#  > Modelo[117, 'promedio'] 8.500
#  > Modelo[118, 'mediana'] 8.786
#  > Modelo[118, 'promedio'] 8.465
#  > Modelo[119, 'mediana'] 8.604
#  > Modelo[119, 'promedio'] 8.407
#  > Modelo[120, 'mediana'] 8.554
#  > Modelo[120, 'promedio'] 8.339
#  > Modelo[121, 'mediana'] 8.510
#  > Modelo[121, 'promedio'] 8.280
#  > Modelo[122, 'mediana'] 8.371
#  > Modelo[122, 'promedio'] 8.246
#  > Modelo[123, 'mediana'] 8.352
#  > Modelo[123, 'promedio'] 8.248
#  > Modelo[124, 'mediana'] 8.418
#  > Modelo[124, 'promedio'] 8.279
#  > Modelo[125, 'mediana'] 8.541
#  > Modelo[125, 'promedio'] 8.333
#  > Modelo[126, 'mediana'] 8.677
#  > Modelo[126, 'promedio'] 8.397
#  > Modelo[127, 'mediana'] 8.804
#  > Modelo[127, 'promedio'] 8.453
#  > Modelo[128, 'mediana'] 8.865
#  > Modelo[128, 'promedio'] 8.487
#  > Modelo[129, 'mediana'] 8.923
#  > Modelo[129, 'promedio'] 8.491
#  > Modelo[130, 'mediana'] 8.779
#  > Modelo[130, 'promedio'] 8.461
#  > Modelo[131, 'mediana'] 8.577
#  > Modelo[131, 'promedio'] 8.409
#  > Modelo[132, 'mediana'] 8.548
#  > Modelo[132, 'promedio'] 8.348
#  > Modelo[133, 'mediana'] 8.521
#  > Modelo[133, 'promedio'] 8.297
#  > Modelo[134, 'mediana'] 8.373
#  > Modelo[134, 'promedio'] 8.267
#  > Modelo[135, 'mediana'] 8.347
#  > Modelo[135, 'promedio'] 8.266
#  > Modelo[136, 'mediana'] 8.411
#  > Modelo[136, 'promedio'] 8.294
#  > Modelo[137, 'mediana'] 8.532
#  > Modelo[137, 'promedio'] 8.341
#  > Modelo[138, 'mediana'] 8.674
#  > Modelo[138, 'promedio'] 8.394
#  > Modelo[139, 'mediana'] 8.813
#  > Modelo[139, 'promedio'] 8.441
#  > Modelo[140, 'mediana'] 8.870
#  > Modelo[140, 'promedio'] 8.470
#  > Modelo[141, 'mediana'] 8.909
#  > Modelo[141, 'promedio'] 8.474
#  > Modelo[142, 'mediana'] 8.781
#  > Modelo[142, 'promedio'] 8.449
#  > Modelo[143, 'mediana'] 8.577
#  > Modelo[143, 'promedio'] 8.401
#  > Modelo[144, 'mediana'] 8.547
#  > Modelo[144, 'promedio'] 8.345
#  > Modelo[145, 'mediana'] 8.522
#  > Modelo[145, 'promedio'] 8.297
#  > Modelo[146, 'mediana'] 8.375
#  > Modelo[146, 'promedio'] 8.268
#  > Modelo[147, 'mediana'] 8.356
#  > Modelo[147, 'promedio'] 8.267
#  > Modelo[148, 'mediana'] 8.422
#  > Modelo[148, 'promedio'] 8.293
#  > Modelo[149, 'mediana'] 8.539
#  > Modelo[149, 'promedio'] 8.337
#  > Modelo[150, 'mediana'] 8.676
#  > Modelo[150, 'promedio'] 8.389
#  > Modelo[151, 'mediana'] 8.805
#  > Modelo[151, 'promedio'] 8.433
#  > Modelo[152, 'mediana'] 8.865
#  > Modelo[152, 'promedio'] 8.459
#  > Modelo[153, 'mediana'] 8.917
#  > Modelo[153, 'promedio'] 8.461
#  > Modelo[154, 'mediana'] 8.800
#  > Modelo[154, 'promedio'] 8.437
#  > Modelo[155, 'mediana'] 8.629
#  > Modelo[155, 'promedio'] 8.394
#  > Modelo[156, 'mediana'] 8.566
#  > Modelo[156, 'promedio'] 8.344
#  > Modelo[157, 'mediana'] 8.509
#  > Modelo[157, 'promedio'] 8.300
#  > Modelo[158, 'mediana'] 8.349
#  > Modelo[158, 'promedio'] 8.275
#  > Modelo[159, 'mediana'] 8.324
#  > Modelo[159, 'promedio'] 8.275
#  > Modelo[160, 'mediana'] 8.421
#  > Modelo[160, 'promedio'] 8.299
#  > Modelo[161, 'mediana'] 8.557
#  > Modelo[161, 'promedio'] 8.338
#  > Modelo[162, 'mediana'] 8.671
#  > Modelo[162, 'promedio'] 8.381
#  > Modelo[163, 'mediana'] 8.778
#  > Modelo[163, 'promedio'] 8.420
#  > Modelo[164, 'mediana'] 8.847
#  > Modelo[164, 'promedio'] 8.445
#  > Modelo[165, 'mediana'] 8.855
#  > Modelo[165, 'promedio'] 8.447
#  > Modelo[166, 'mediana'] 8.751
#  > Modelo[166, 'promedio'] 8.426
#  > Modelo[167, 'mediana'] 8.604
#  > Modelo[167, 'promedio'] 8.387
#  > Modelo[168, 'mediana'] 8.547
#  > Modelo[168, 'promedio'] 8.341
#  > Modelo[169, 'mediana'] 8.499
#  > Modelo[169, 'promedio'] 8.301
#  > Modelo[170, 'mediana'] 8.368
#  > Modelo[170, 'promedio'] 8.280
#  > Modelo[171, 'mediana'] 8.353
#  > Modelo[171, 'promedio'] 8.282
#  > Modelo[172, 'mediana'] 8.441
#  > Modelo[172, 'promedio'] 8.307
#  > Modelo[173, 'mediana'] 8.573
#  > Modelo[173, 'promedio'] 8.346
#  > Modelo[174, 'mediana'] 8.679
#  > Modelo[174, 'promedio'] 8.389
#  > Modelo[175, 'mediana'] 8.779
#  > Modelo[175, 'promedio'] 8.425
#  > Modelo[176, 'mediana'] 8.813
#  > Modelo[176, 'promedio'] 8.445
#  > Modelo[177, 'mediana'] 8.792
#  > Modelo[177, 'promedio'] 8.445
#  > Modelo[178, 'mediana'] 8.711
#  > Modelo[178, 'promedio'] 8.425
#  > Modelo[179, 'mediana'] 8.605
#  > Modelo[179, 'promedio'] 8.389
#  > Modelo[180, 'mediana'] 8.547
#  > Modelo[180, 'promedio'] 8.348
#  > Modelo[181, 'mediana'] 8.497
#  > Modelo[181, 'promedio'] 8.312
#  > Modelo[182, 'mediana'] 8.419
#  > Modelo[182, 'promedio'] 8.291
#  > Modelo[183, 'mediana'] 8.412
#  > Modelo[183, 'promedio'] 8.292
#  > Modelo[184, 'mediana'] 8.456
#  > Modelo[184, 'promedio'] 8.312
#  > Modelo[185, 'mediana'] 8.572
#  > Modelo[185, 'promedio'] 8.348
#  > Modelo[186, 'mediana'] 8.674
#  > Modelo[186, 'promedio'] 8.387
#  > Modelo[187, 'mediana'] 8.776
#  > Modelo[187, 'promedio'] 8.421
#  > Modelo[188, 'mediana'] 8.782
#  > Modelo[188, 'promedio'] 8.440
#  > Modelo[189, 'mediana'] 8.714
#  > Modelo[189, 'promedio'] 8.441
#  > Modelo[190, 'mediana'] 8.668
#  > Modelo[190, 'promedio'] 8.423
#  > Modelo[191, 'mediana'] 8.598
#  > Modelo[191, 'promedio'] 8.392
#  > Modelo[192, 'mediana'] 8.550
#  > Modelo[192, 'promedio'] 8.354
# terminado
# [1, 'mediana'] 5.143604443060009
# [1, 'promedio'] 5.143604443060009
# [2, 'mediana'] 6.595216069242917

# %%
encontrar_mejor_solucion(series, nombre, metodo = "exp")
# Out:
# Tamaño Entrenamiento 192
# Tamaño Prueba 48
# Encontrando la mejor solución para exp
# terminado
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 encontrar_mejor_solucion(series, nombre, metodo = "exp")
#
# Cell In[7], line 43, in encontrar_mejor_solucion(series, nombre, metodo, muestra)
#      41 # desplegar
#      42 entreno, prueba = division_entreno_prueba(datos, n_prueba)
# ---> 43 prediccion = pd.DataFrame(list(entreno.flatten()) + resultados[0][2])
#      44 ax = pd.DataFrame(datos).plot(label = "Original") # Datos originales
#      45 prediccion.plot(ax = ax, alpha = .7, figsize = (14,7))
#
# IndexError: list index out of range

# %% [markdown]
# # Caso: Con Tendencia y con Estacionalidad -  Venta mensual de carros

# %%
series = pd.read_csv('monthly-car-sales.csv', header = 0,parse_dates = ["Month"])
series.set_index(['Month'], inplace = True)
import seaborn; seaborn.set()
series.plot(figsize = (16,10))
plt.savefig('cars.png')

# %%
series = pd.read_csv('monthly-car-sales.csv', header=0, index_col=0)
nombre = "carros"
encontrar_mejor_solucion(series, nombre, metodo = "promedio")
encontrar_mejor_solucion(series, nombre, metodo = "sarima")
encontrar_mejor_solucion(series, nombre, metodo = "exp")
